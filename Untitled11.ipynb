# %% [markdown]
# <a href="https://colab.research.google.com/github/salaarmir/arcticice/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/N_04_extent_v3.0.csv')
df.head()
# Out:
#    year   mo      data-type   region   extent     area
# 0  1979    4        Goddard        N    15.45    12.53
# 1  1980    4        Goddard        N    15.43    12.52
# 2  1981    4        Goddard        N    15.01    12.24
# 3  1982    4        Goddard        N    15.47    12.63
# 4  1983    4        Goddard        N    15.17    12.21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           45 non-null     int64
#  1    mo            45 non-null     int64
#  2       data-type  45 non-null     object
#  3    region        45 non-null     object
#  4    extent        45 non-null     float64
#  5      area        45 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.2+ KB

# %%
df.isnull().sum()
# Out:
# year             0
#  mo              0
#     data-type    0
#  region          0
#  extent          0
#    area          0
# dtype: int64

# %%
print("hello world")
# Out:
# hello world
